# %% [markdown]
# <a href="https://colab.research.google.com/github/hrnn/image-processing-practice/blob/main/opencv_class_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/gdrive/My Drive/Colab Notebooks/opencv/circles.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=754x585 at 0x7F6B5F7F9090>

# %%
blue, green, red = cv2.split(img)
cv2_imshow(blue)
# Out:
# <PIL.Image.Image image mode=L size=754x585 at 0x7F6B5B7AC390>

# %%
cv2_imshow(green)
# Out:
# <PIL.Image.Image image mode=L size=754x585 at 0x7F6B5B7F20D0>

# %%
cv2_imshow(red)
# Out:
# <PIL.Image.Image image mode=L size=754x585 at 0x7F6B5B7B8150>

# %%
img_rbg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(img_rbg)
# Out:
# <PIL.Image.Image image mode=RGB size=754x585 at 0x7F6B5B71E210>

# %%
img.shape
# Out:
# (585, 754, 3)

# %%
corners = img[0:180,0:180]
cv2_imshow(corners)
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x7F6B5B6E8690>

# %%
green_color = (0, 255, 0)
img[0:100,0:100] = green_color
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=754x585 at 0x7F6B5B6E8510>
